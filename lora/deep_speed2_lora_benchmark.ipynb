# %%
# For Colab users uncomment the following lines to install required packages
# !pip install lm_eval  langdetect -q
# !pip install git+https://github.com/felipemaiapolo/tinyBenchmarks

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from lm_eval import evaluator
from joblib import dump
import wandb
import numpy as np

# %%
# Login to Weights & Biases
wandb.login()

# %%
# Create W&B and run
wandb.init(project="phi4_african_history", name="phi4_african_history_lora_ds2_bench_mark")
# Out:
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/content/wandb/run-20260124_071337-rhiavw3y</code>
# Syncing run <strong><a href='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history/runs/rhiavw3y' target="_blank">phi4_african_history_lora_ds2_bench_mark</a></strong> to <a href='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history' target="_blank">https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history</a>
#  View run at <a href='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history/runs/rhiavw3y' target="_blank">https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history/runs/rhiavw3y</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history/runs/rhiavw3y?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# Define your IDs
base_model_id = "microsoft/Phi-4-mini-instruct"
lora_adapter_id = "DannyAI/phi4_african_history_lora_ds2" # Your HF path

# %%
config = {
    # "model": lora_model,
    "tasks": [
              "tinyTruthfulQA",
              "tinyMMLU"
              ],
    "batch_size": 4,
}

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

results = evaluator.simple_evaluate(
    model="hf",
    model_args=f"pretrained={base_model_id},peft={lora_adapter_id},parallelize=True,trust_remote_code=False",
    tasks=config["tasks"],
    device=device,
    batch_size=config["batch_size"],
)


dump(results, "evaluation_results.joblib")

# %%
results['results']
# Out:
# {'tinyMMLU': {'alias': 'tinyMMLU',
#   'acc_norm,none': np.float64(0.677877432857976),
#   'acc_norm_stderr,none': 'N/A'},
#  'tinyTruthfulQA': {'alias': 'tinyTruthfulQA',
#   'acc,none': np.float64(0.4382211287739072),
#   'acc_stderr,none': 'N/A'}}

# %%
# Clean and flatten the dictionary
summary_metrics = {}

for task, metrics in results['results'].items():
    for metric_name, value in metrics.items():
        # Only log numeric values, skip 'alias' and 'N/A'
        if isinstance(value, (int, float, np.float64)):
            # Create a clean name, e.g., "tinyMMLU/acc_norm"
            clean_name = f"{task}/{metric_name.replace(',none', '')}"
            summary_metrics[clean_name] = float(value)

# Log onto active W&B run
wandb.log(summary_metrics)

# Finish & sync data immediately
wandb.finish()
print("Results successfully synced to W&B!")
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>tinyMMLU/acc_norm</td><td>▁</td></tr><tr><td>tinyTruthfulQA/acc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>tinyMMLU/acc_norm</td><td>0.67788</td></tr><tr><td>tinyTruthfulQA/acc</td><td>0.43822</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">phi4_african_history_lora_ds2_bench_mark</strong> at: <a href='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history/runs/rhiavw3y' target="_blank">https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history/runs/rhiavw3y</a><br> View project at: <a href='https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history' target="_blank">https://wandb.ai/dannyai-danny-the-analyst/phi4_african_history</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_071337-rhiavw3y/logs</code>
# Results successfully synced to W&B!
